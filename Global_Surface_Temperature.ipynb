# %%
#importing CSV File and Reading it
import pandas as pd
import csv
df= pd.read_csv("GlobalLandTemperaturesByCountry.csv", sep=',', encoding='latin-1')
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# 5       1744-04-01               1.530                          4.680
# 6       1744-05-01               6.702                          1.789
# 7       1744-06-01              11.609                          1.577
# 8       1744-07-01              15.342                          1.410
# 9       1744-08-01                 NaN                            NaN
# 10      1744-09-01              11.702                          1.517
# 11      1744-10-01               5.477                          1.862
# ...

# %%
df['dt'].dtype
# Out:
# dtype('O')

# %%
df['dt'] = pd.to_datetime(df['dt'])
df['dt']
# Out:
# 0        1743-11-01 00:00:00
# 1        1743-12-01 00:00:00
# 2        1744-01-01 00:00:00
# 3        1744-02-01 00:00:00
# 4        1744-03-01 00:00:00
# 5        1744-04-01 00:00:00
# 6        1744-05-01 00:00:00
# 7        1744-06-01 00:00:00
# 8        1744-07-01 00:00:00
# 9        1744-08-01 00:00:00
# 10       1744-09-01 00:00:00
# 11       1744-10-01 00:00:00
# 12       1744-11-01 00:00:00
# 13       1744-12-01 00:00:00
# 14       1745-01-01 00:00:00
# 15       1745-02-01 00:00:00
# 16       1745-03-01 00:00:00
# 17       1745-04-01 00:00:00
# 18       1745-05-01 00:00:00
# 19       1745-06-01 00:00:00
# 20       1745-07-01 00:00:00
# 21       1745-08-01 00:00:00
# 22       1745-09-01 00:00:00
# 23       1745-10-01 00:00:00
# 24       1745-11-01 00:00:00
# 25       1745-12-01 00:00:00
# 26       1746-01-01 00:00:00
# 27       1746-02-01 00:00:00
# 28       1746-03-01 00:00:00
# 29       1746-04-01 00:00:00
#                  ...
# 577432            2011-04-01
# ...

# %%
df[(df['dt'] > '1980-01-01')]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty   Country
# 2835   1980-02-01              -6.484                          0.441    Ãland
# 2836   1980-03-01              -3.947                          0.466    Ãland
# 2837   1980-04-01               2.928                          0.597    Ãland
# 2838   1980-05-01               6.154                          0.241    Ãland
# 2839   1980-06-01              13.999                          0.642    Ãland
# 2840   1980-07-01              16.320                          0.366    Ãland
# 2841   1980-08-01              15.173                          0.367    Ãland
# 2842   1980-09-01              12.852                          0.223    Ãland
# 2843   1980-10-01               6.433                          0.284    Ãland
# 2844   1980-11-01               0.636                          0.511    Ãland
# 2845   1980-12-01               0.197                          0.234    Ãland
# ...

# %%
df.to_csv("Global_Surface_Temp_filtered.csv",encoding='utf-8')
