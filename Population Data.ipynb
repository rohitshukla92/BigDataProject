# %%
#importing CSV File and Reading it
import pandas as pd
import csv

df= pd.read_csv("midyear_population_age_country_code.csv", sep=',', encoding='latin-1')
df
# Out:
#         country_code               country_name  year     sex  max_age  \
# 0                 CV                 Cabo Verde  2033  Female      100
# 1                 TW                     Taiwan  1994    Male      100
# 2                 GR                     Greece  2032    Male      100
# 3                 RS                     Russia  2045    Male      100
# 4                 MZ                 Mozambique  1989    Male      100
# 5                 BD                    Bermuda  2041  Female      100
# 6                 GV                     Guinea  1978    Male       97
# 7                 BX                     Brunei  1991    Male      100
# 8                 ES                El Salvador  2046  Female      100
# 9                 SL               Sierra Leone  2000    Male      100
# 10                SC      Saint Kitts and Nevis  2013  Female      100
# 11                UZ                 Uzbekistan  2025    Male      100
# ...
